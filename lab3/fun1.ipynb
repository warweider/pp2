# %%
def converter(grams):
    return 28.3495231 * grams
grams = float(input())
ounces = converter(grams)
print("ounces:", ounces)
# Out:
# ounces: 340.1942772

# %%
def farenheit(f):
    return (5 / 9) * (f - 32)
f = float(input())
c = farenheit(f)
print(c)
# Out:
# -11.11111111111111

# %%
def solve(numheads, numlegs):
    if (numlegs - 2 * numheads) % 2 != 0:
        return "No solution number of legs must be even."
    y = (numlegs - 2 * numheads) // 2
    x = numheads - y
    if x < 0 or y < 0:
        return "No solution negative number of animals isn't possible."
    return x, y

numheads = 35
numlegs = 94
result = solve(numheads, numlegs)
print(result)
# Out:
# (23, 12)
